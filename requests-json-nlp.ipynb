# %%
# Create and activate a Python virtual environment. 
# Before starting the project, try all these imports FIRST
# Address any errors you get running this code cell 
# by installing the necessary packages into your active Python environment.
# Try to resolve issues using your materials and the web.
# If that doesn't work, ask for help in the discussion forums.
# You can't complete the exercises until you import these - start early! 
# We also import json and pickle (included in the Python Standard Library).

import json
import pickle

import requests
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

print('All prereqs installed.')
# !pip list
# Out:
# All prereqs installed.
# Package                       Version
# ----------------------------- ---------
# alabaster                     0.7.12
# anaconda-client               1.11.2
# anaconda-navigator            2.4.0
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.2.1
# appnope                       0.1.2
# appscript                     1.1.2
# argh                          0.26.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# asgiref                       3.7.2
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# autopep8                      1.5.6
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# backports.zoneinfo            0.2.1
# bayesian-optimization         1.2.0
# bcrypt                        3.2.0
# beautifulsoup4                4.12.2
# binaryornot                   0.4.4
# black                         23.7.0
# bleach                        4.1.0
# blis                          0.7.9
# bokeh                         3.1.1
# Bottleneck                    1.3.5
# branca                        0.6.0
# brotlipy                      0.7.0
# catalogue                     2.0.8
# catboost                      1.0.6
# certifi                       2022.12.7
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.6
# colorcet                      3.0.1
# comm                          0.1.2
# conda                         4.11.0
# conda-build                   3.21.4
# conda-content-trust           0.1.3
# conda-package-handling        2.0.2
# conda_package_streaming       0.7.0
# conda-repo-cli                1.0.41
# conda-token                   0.4.0
# conda-verify                  3.4.2
# confection                    0.1.0
# constantly                    15.1.0
# contextvars                   2.4
# contourpy                     1.0.5
# cookiecutter                  2.1.1
# cryptography                  39.0.1
# cssselect                     1.1.0
# cycler                        0.11.0
# cymem                         2.0.7
# cytoolz                       0.12.0
# dask                          2023.3.2
# datashader                    0.14.4
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.6
# distlib                       0.3.6
# distributed                   2023.3.2
# docutils                      0.18.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.16.2
# filelock                      3.12.2
# flake8                        3.9.0
# Flask                         2.2.2
# fonttools                     4.25.0
# fsspec                        2023.3.0
# future                        0.18.3
# gensim                        4.3.0
# glob2                         0.7
# gmpy2                         2.1.2
# graphviz                      0.19.1
# greenlet                      2.0.1
# h11                           0.14.0
# h5py                          3.7.0
# HeapDict                      1.0.1
# holoviews                     1.16.2
# htmltools                     0.2.1
# huggingface-hub               0.10.1
# hvplot                        0.8.4
# hyperlink                     21.0.0
# idna                          3.4
# imagecodecs                   2021.8.26
# imageio                       2.26.0
# imagesize                     1.4.1
# imbalanced-learn              0.10.1
# immutables                    0.19
# importlib-metadata            6.0.0
# importlib-resources           5.2.0
# incremental                   21.3.0
# iniconfig                     1.1.1
# intake                        0.6.8
# intervaltree                  3.1.0
# ipykernel                     6.19.2
# ipyleaflet                    0.17.3
# ipython                       8.12.0
# ipython-genutils              0.2.0
# ipywidgets                    8.0.7
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jaraco.classes                3.2.1
# jedi                          0.17.2
# Jinja2                        3.1.2
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.1
# json5                         0.9.6
# jsonschema                    4.17.3
# jupyter                       1.0.0
# jupyter-bokeh                 3.0.7
# jupyter_client                8.1.0
# jupyter-console               6.6.2
# jupyter_core                  5.3.0
# jupyter-server                1.23.4
# jupyterlab                    3.5.3
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.22.0
# jupyterlab-widgets            3.0.8
# keyring                       23.13.1
# kiwisolver                    1.4.4
# langcodes                     3.3.0
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# lightgbm                      3.3.2
# linkify-it-py                 2.0.2
# llvmlite                      0.39.1
# locket                        1.0.0
# lxml                          4.9.2
# lz4                           3.1.3
# Markdown                      3.4.1
# markdown-it-py                3.0.0
# MarkupSafe                    2.1.1
# mathjax                       0.1.2
# matplotlib                    3.7.2
# matplotlib-inline             0.1.6
# mccabe                        0.6.1
# mdit-py-plugins               0.4.0
# mdurl                         0.1.2
# mistune                       0.8.4
# mizani                        0.9.2
# mock                          4.0.3
# more-itertools                8.12.0
# mpmath                        1.2.1
# msgpack                       1.0.3
# multipledispatch              0.6.0
# munkres                       1.1.4
# murmurhash                    1.0.9
# mypy-extensions               0.4.3
# navigator-updater             0.3.0
# nbclassic                     0.5.5
# nbclient                      0.5.13
# nbconvert                     6.5.4
# nbformat                      5.7.0
# nest-asyncio                  1.5.6
# networkx                      2.8.4
# nltk                          3.7
# nodeenv                       1.8.0
# notebook                      6.5.4
# notebook_shim                 0.2.2
# numba                         0.56.4
# numexpr                       2.8.4
# numpy                         1.23.5
# numpydoc                      1.5.0
# openpyxl                      3.1.2
# packaging                     23.0
# pandas                        2.0.3
# pandocfilters                 1.5.0
# panel                         1.2.0
# param                         1.12.3
# parsel                        1.6.0
# parso                         0.7.0
# partd                         1.2.0
# pathspec                      0.10.3
# pathy                         0.10.2
# patsy                         0.5.3
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.4.0
# pip                           23.2
# pkginfo                       1.9.6
# pkgutil_resolve_name          1.3.10
# platformdirs                  3.8.1
# plotly                        5.15.0
# plotnine                      0.12.1
# pluggy                        1.0.0
# pooch                         1.4.0
# preshed                       3.0.8
# prometheus-client             0.14.1
# prompt-toolkit                3.0.36
# Protego                       0.1.16
# psutil                        5.9.0
# psycopg2-binary               2.9.6
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.6.0
# pycosat                       0.6.4
# pycparser                     2.21
# pyct                          0.5.0
# pycurl                        7.45.2
# pydantic                      1.10.11
# PyDispatcher                  2.0.5
# pydocstyle                    6.3.0
# pydotplus                     2.0.2
# pyerfa                        2.0.0
# pyflakes                      2.2.0
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.4.0
# pylint                        2.16.2
# pyls-black                    0.4.6
# pyls-spyder                   0.3.2
# pyodbc                        4.0.34
# pyOpenSSL                     23.0.0
# pyparsing                     3.0.9
# pyright                       1.1.317
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.2
# python-dateutil               2.8.2
# python-dotenv                 0.19.1
# python-jsonrpc-server         0.4.0
# python-language-server        0.36.2
# python-multipart              0.0.6
# python-slugify                6.1.2
# python-snappy                 0.6.1
# pytoolconfig                  1.2.5
# pytz                          2022.7
# pyviz-comms                   2.0.2
# PyWavelets                    1.4.1
# PyYAML                        6.0
# pyzmq                         23.2.0
# QDarkStyle                    2.8.1
# QtAwesome                     1.2.2
# qtconsole                     5.4.2
# QtPy                          2.2.0
# queuelib                      1.5.0
# regex                         2022.7.9
# requests                      2.28.1
# requests-file                 1.5.1
# requests-toolbelt             0.9.1
# rope                          1.7.0
# rsconnect-python              1.19.0
# Rtree                         1.0.1
# ruamel-yaml-conda             0.15.100
# ruff                          0.0.278
# scikit-image                  0.19.3
# scikit-learn                  1.2.2
# scipy                         1.10.1
# Scrapy                        2.8.0
# seaborn                       0.12.2
# semver                        2.13.0
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    66.0.0
# shiny                         0.4.0
# shinyswatch                   0.2.4
# shinywidgets                  0.2.1
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soupsieve                     2.4
# spacy                         3.6.0
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.4
# spacytextblob                 4.0.0
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        4.2.5
# spyder-kernels                1.10.2
# SQLAlchemy                    1.4.39
# srsly                         2.4.6
# stack-data                    0.2.0
# starlette                     0.30.0
# statsmodels                   0.14.0
# sympy                         1.11.1
# tables                        3.7.0
# tabulate                      0.8.10
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# terminado                     0.17.1
# text-unidecode                1.3
# textblob                      0.15.3
# textdistance                  4.2.1
# thinc                         8.1.10
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss2                      1.2.1
# tldextract                    3.2.0
# tokenizers                    0.11.4
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.12.0
# torch                         1.13.1
# tornado                       6.2
# tqdm                          4.65.0
# traitlets                     5.7.1
# traittypes                    0.2.1
# transformers                  4.24.0
# turtle                        0.0.1
# Twisted                       22.2.0
# typer                         0.9.0
# typing_extensions             4.5.0
# tzdata                        2023.3
# uc-micro-py                   1.0.2
# ujson                         5.4.0
# urllib3                       1.26.15
# uvicorn                       0.23.0
# virtualenv                    20.23.1
# w3lib                         1.21.0
# wasabi                        1.1.2
# watchdog                      1.0.2
# watchfiles                    0.19.0
# watermark                     2.3.1
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# websockets                    11.0.3
# Werkzeug                      2.2.3
# wheel                         0.40.0
# widgetsnbextension            4.0.8
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# wurlitzer                     3.0.2
# xarray                        2022.11.0
# xlwings                       0.29.1
# XStatic-bootswatch            3.3.7.0
# xyzservices                   2023.7.0
# yapf                          0.31.0
# zict                          2.1.0
# zipp                          3.11.0
# zope.interface                5.4.0
# zstandard                     0.19.0

# %%
conda -V
python
# Out:
#   Cell In[5], line 2
#     python$
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Web Mining and Applied NLP (44-620)
#
# ## Requests, JSON, and NLP
#
# ### Student Name:
#
# Perform the tasks described in the Markdown cells below.  When you have completed the assignment make sure your code cells have all been run (and have output beneath them) and ensure you have committed and pushed ALL of your changes to your assignment repository.
#
# Make sure you have [installed spaCy and its pipeline](https://spacy.io/usage#quickstart) and [spaCyTextBlob](https://spacy.io/universe/project/spacy-textblob)
#
# Every question that requires you to write code will have a code cell underneath it; you may either write your entire solution in that cell or write it in a python file (`.py`), then import and run the appropriate code to answer the question.
#
# This assignment requires that you write additional files (either JSON or pickle files); make sure to submit those files in your repository as well.

# %% [markdown]
# 1. The following code accesses the [lyrics.ovh](https://lyricsovh.docs.apiary.io/#reference/0/lyrics-of-a-song/search) public api, searches for the lyrics of a song, and stores it in a dictionary object.  Write the resulting json to a file (either a JSON file or a pickle file; you choose). You will read in the contents of this file for future questions so we do not need to frequently access the API.

# %%
pip install lyricsgenius
# Out:
# Collecting lyricsgenius
#   Downloading lyricsgenius-3.0.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /Users/ashleymersman/opt/anaconda3/lib/python3.8/site-packages (from lyricsgenius) (4.12.2)
# Requirement already satisfied: requests>=2.20.0 in /Users/ashleymersman/opt/anaconda3/lib/python3.8/site-packages (from lyricsgenius) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/ashleymersman/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4>=4.6.0->lyricsgenius) (2.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ashleymersman/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->lyricsgenius) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ashleymersman/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->lyricsgenius) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ashleymersman/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->lyricsgenius) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ashleymersman/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->lyricsgenius) (2022.12.7)
# Installing collected packages: lyricsgenius
# Successfully installed lyricsgenius-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json

# result = json.loads(requests.get('https://api.lyrics.ovh/v1/They Might Be Giants/Birdhouse in your soul').text)
import lyricsgenius
# Create lyricsgenius object
genius = lyricsgenius.Genius(access_token)
#  result = requests.get('http://api.chartlyrics.com/apiv1.asmx/SearchLyricDirect?artist='TaylorSwift'&song='+song).text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5 import lyricsgenius
#       6 # Create lyricsgenius object
# ----> 7 genius = lyricsgenius.Genius()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/lyricsgenius/genius.py:76, in Genius.__init__(self, access_token, response_format, timeout, sleep_time, verbose, remove_section_headers, skip_non_songs, excluded_terms, replace_default_terms, retries)
#      68 def __init__(self, access_token=None,
#      69              response_format='plain', timeout=5, sleep_time=0.2,
#      70              verbose=True, remove_section_headers=False,
#    (...)
#      74              ):
#      75     # Genius Client Constructor
# ---> 76     super().__init__(
#      77         access_token=access_token,
#      78         response_format=response_format,
#      79         timeout=timeout,
#      80         sleep_time=sleep_time,
#      81         retries=retries
#      82     )
#      84     self.verbose = verbose
#      85     self.remove_section_headers = remove_section_headers
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/lyricsgenius/api/api.py:59, in API.__init__(self, access_token, response_format, timeout, sleep_time, retries)
#      52 def __init__(self,
#      53              access_token,
#      54              response_format='plain',
#    (...)
#      57              retries=0,
#      58              ):
# ---> 59     super().__init__(
#      60         access_token=access_token,
#      61         response_format=response_format,
#      62         timeout=timeout,
#      63         sleep_time=sleep_time,
#      64         retries=retries,
#      65     )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/lyricsgenius/api/api.py:535, in PublicAPI.__init__(self, response_format, timeout, sleep_time, retries, **kwargs)
#     532 public_api_constructor = False if self.__class__.__name__ == 'Genius' else True
#     534 # Genius PublicAPI Constructor
# --> 535 super().__init__(
#     536     response_format=response_format,
#     537     timeout=timeout,
#     538     sleep_time=sleep_time,
#     539     retries=retries,
#     540     public_api_constructor=public_api_constructor,
#     541     **kwargs
#     542 )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/lyricsgenius/api/base.py:37, in Sender.__init__(self, access_token, response_format, timeout, sleep_time, retries, public_api_constructor)
#      35 else:
#      36     if not access_token or not isinstance(access_token, str):
# ---> 37         raise TypeError('Invalid token')
#      38     self.access_token = 'Bearer ' + access_token
#      39     self.authorization_header = {'authorization': self.access_token}
#
# TypeError: Invalid token

# %% [markdown]
# 2. Read in the contents of your file.  Print the lyrics of the song (not the entire dictionary!) and use spaCyTextBlob to perform sentiment analysis on the lyrics.  Print the polarity score of the sentiment analysis.  Given that the range of the polarity score is `[-1.0,1.0]` which corresponds to how positive or negative the text in question is, do you think the lyrics have a more positive or negative connotaion?  Answer this question in a comment in your code cell.

# %% [markdown]
# 3. Write a function that takes an artist, song, and filename, accesses the lyrics.ovh api to get the song lyrics, and writes the results to the specified filename.  Test this function by getting the lyrics to any four songs of your choice and storing them in different files.

# %% [markdown]
# 4. Write a function that takes the name of a file that contains song lyrics, loads the file, performs sentiment analysis, and returns the polarity score.  Use this function to print the polarity scores (with the name of the song) of the three files you created in question 3.  Does the reported polarity match your understanding of the song's lyrics? Why or why not do you think that might be?  Answer the questions in either a comment in the code cell or a markdown cell under the code cell.
